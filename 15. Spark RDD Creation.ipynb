# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark import SparkContext
# Out:
# StatementMeta(, b12f7104-1de5-46df-9432-e7ef73ee67e0, 3, Finished, Available, Finished, False)

# %%
sc=SparkContext.getOrCreate()
# Out:
# StatementMeta(, b12f7104-1de5-46df-9432-e7ef73ee67e0, 4, Finished, Available, Finished, False)

# %%
lst=[1,2,3]
rdd1=sc.parallelize(lst)
# Out:
# StatementMeta(, df904d8b-f997-4ffe-bbe4-7b6bdb1742d7, 7, Finished, Available, Finished, False)

# %%
type(rdd1)
# Out:
# StatementMeta(, df904d8b-f997-4ffe-bbe4-7b6bdb1742d7, 8, Finished, Available, Finished, False)
# pyspark.rdd.RDD

# %%
import pyspark
rdd_methods=dir(pyspark.rdd.RDD)
lst_methods=dir(list)
# Out:
# StatementMeta(, df904d8b-f997-4ffe-bbe4-7b6bdb1742d7, 14, Finished, Available, Finished, False)

# %%
import pandas as pd

data1={'RDD Methods':rdd_methods}
data2={'List Methods':lst_methods}
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
# Out:
# StatementMeta(, df904d8b-f997-4ffe-bbe4-7b6bdb1742d7, 32, Finished, Available, Finished, False)

# %%
type(sc)
# Out:
# StatementMeta(, df904d8b-f997-4ffe-bbe4-7b6bdb1742d7, 35, Finished, Available, Finished, False)
# pyspark.context.SparkContext

# %%
spark_sc_methods=dir(pyspark.context.SparkContext)
# Out:
# StatementMeta(, df904d8b-f997-4ffe-bbe4-7b6bdb1742d7, 37, Finished, Available, Finished, False)

# %%
df3=pd.DataFrame({'Spark Context Methods': spark_sc_methods})
# Out:
# StatementMeta(, df904d8b-f997-4ffe-bbe4-7b6bdb1742d7, 39, Finished, Available, Finished, False)

# %%
df_final=pd.concat([df1,df2,df3],ignore_index=True)
display(df_final)
# Out:
# StatementMeta(, df904d8b-f997-4ffe-bbe4-7b6bdb1742d7, 46, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 9b523fd5-c34f-4357-aad5-084fcdbe5624)

# %%
lst=[1,2,3]

rdd_1=sc.parallelize(lst)#Defualt it is 8
print(rdd_1.getNumPartitions())

rdd1=sc.parallelize(lst,2)
# Out:
# StatementMeta(, df904d8b-f997-4ffe-bbe4-7b6bdb1742d7, 55, Finished, Available, Finished, False)
# 8

# %%
rdd1.glom().collect()
# Out:
# StatementMeta(, df904d8b-f997-4ffe-bbe4-7b6bdb1742d7, 56, Finished, Available, Finished, False)
# [[1], [2, 3]]

# %%
path='abfss://hymaa_practice_2026@onelake.dfs.fabric.microsoft.com/lh_raw.Lakehouse/Files/'
# Out:
# StatementMeta(, b12f7104-1de5-46df-9432-e7ef73ee67e0, 6, Finished, Available, Finished, False)

# %%
rdd2=sc.textFile(path+'/CSV/hdfc_orders_creditcard_07022026.csv',2)
# Out:
# StatementMeta(, b12f7104-1de5-46df-9432-e7ef73ee67e0, 7, Finished, Available, Finished, False)

# %%
rdd2.glom().collect()
# Out:
# StatementMeta(, b12f7104-1de5-46df-9432-e7ef73ee67e0, 12, Finished, Available, Finished, False)
# [['order_id,order_id,order_amount'], ['01,101,2000', '02,102,3000']]

# %%
lst=[1,2,3,4]
rdd1=sc.parallelize(lst,2)
rdd1.glom().collect()
# Out:
# StatementMeta(, 25a0f8fe-2543-47af-ba5d-b7cbef8a4880, 4, Finished, Available, Finished, False)
# [[1, 2], [3, 4]]

# %%
rdd2=rdd1.map(lambda x: x*2)
rdd2.glom().collect()
# Out:
# StatementMeta(, 25a0f8fe-2543-47af-ba5d-b7cbef8a4880, 6, Finished, Available, Finished, False)
# [[2, 4], [6, 8]]

# %%
rdd2=rdd1.map(lambda x: (x,1))
rdd2.glom().collect()
# Out:
# StatementMeta(, 25a0f8fe-2543-47af-ba5d-b7cbef8a4880, 8, Finished, Available, Finished, False)
# [[(1, 1), (2, 1)], [(3, 1), (4, 1)]]

# %%
rdd2=rdd1.filter(lambda x: x%2==1)
rdd2.glom().collect()
# Out:
# StatementMeta(, 25a0f8fe-2543-47af-ba5d-b7cbef8a4880, 9, Finished, Available, Finished, False)
# [[1], [3]]
